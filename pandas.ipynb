# %% [markdown]
# <a href="https://colab.research.google.com/github/kalijauhari/Pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dict = {
    "name" : ['kali', 'kavita', 'shubhangi'],
    "marks" : [98,99,10],
    "city" : ['delhi','mumbai','bangalore']
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#         name  marks       city
# 0       kali     98      delhi
# 1     kavita     99     mumbai
# 2  shubhangi     10  bangalore

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_ind.csv', index=False)

# %%
df.head(2)
# Out:
#      name  marks    city
# 0    kali     98   delhi
# 1  kavita     99  mumbai

# %%
df.tail(2)
# Out:
#         name  marks       city
# 1     kavita     99     mumbai
# 2  shubhangi     10  bangalore

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   69.000000
# std    51.097945
# min    10.000000
# 25%    54.000000
# 50%    98.000000
# 75%    98.500000
# max    99.000000

# %%
abc = pd.read_csv("https://raw.githubusercontent.com/kalijauhari/Pandas/main/weather.csv")

# %%
abc
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
abc['MinTemp']
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
abc['MinTemp'][0]
# Out:
# 8.0

# %%
abc['MinTemp'][0] = 9.0
# Out:
# <ipython-input-38-0c73a8c13229>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abc['MinTemp'][0] = 9.0

# %%
abc['MinTemp'][0]
# Out:
# 9.0

# %%
df
# Out:
#         name  marks       city
# 0       kali     98      delhi
# 1     kavita     99     mumbai
# 2  shubhangi     10  bangalore

# %%
df['marks'][0] = 99
# Out:
# <ipython-input-41-3dd285956b61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marks'][0] = 99

# %%
df['marks'][0]
# Out:
# 99

# %%
df.index = ['first','second','third']

# %%
df
# Out:
#              name  marks       city
# first        kali     99      delhi
# second     kavita     99     mumbai
# third   shubhangi     10  bangalore

# %%
ser = pd.Series(np.random.rand(5))

# %%
ser
# Out:
# 0    0.413908
# 1    0.249655
# 2    0.624294
# 3    0.485725
# 4    0.445418
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(12,3),index=np.arange(12))

# %%
newdf
# Out:
#            0         1         2
# 0   0.622493  0.788445  0.867439
# 1   0.753733  0.401856  0.030838
# 2   0.049101  0.393013  0.543733
# 3   0.947437  0.340978  0.962509
# 4   0.163570  0.179510  0.674561
# 5   0.774367  0.962417  0.636606
# 6   0.658237  0.912069  0.515689
# 7   0.245886  0.691089  0.380715
# 8   0.836300  0.864545  0.153341
# 9   0.776664  0.068195  0.487569
# 10  0.529771  0.308509  0.851256
# 11  0.124794  0.838086  0.452129

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.to_numpy()
# Out:
# array([[0.62249287, 0.7884455 , 0.86743928],
#        [0.75373325, 0.40185642, 0.03083822],
#        [0.04910093, 0.39301313, 0.54373293],
#        [0.9474374 , 0.34097829, 0.9625089 ],
#        [0.16357047, 0.17950979, 0.67456096],
#        [0.77436736, 0.96241706, 0.63660633],
#        [0.65823717, 0.91206902, 0.51568874],
#        [0.24588615, 0.69108889, 0.38071505],
#        [0.83629994, 0.86454466, 0.15334121],
#        [0.77666353, 0.06819507, 0.48756878],
#        [0.52977069, 0.30850855, 0.85125615],
#        [0.12479444, 0.83808578, 0.45212864]])

# %%
newdf.T #transpose
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.622493  0.753733  0.049101  0.947437  0.163570  0.774367  0.658237
# 1  0.788445  0.401856  0.393013  0.340978  0.179510  0.962417  0.912069
# 2  0.867439  0.030838  0.543733  0.962509  0.674561  0.636606  0.515689
#
#          7         8         9         10        11
# 0  0.245886  0.836300  0.776664  0.529771  0.124794
# 1  0.691089  0.864545  0.068195  0.308509  0.838086
# 2  0.380715  0.153341  0.487569  0.851256  0.452129

# %%
newdf.sort_index(axis=0,ascending=False)
# Out:
#            0         1         2
# 11  0.124794  0.838086  0.452129
# 10  0.529771  0.308509  0.851256
# 9   0.776664  0.068195  0.487569
# 8   0.836300  0.864545  0.153341
# 7   0.245886  0.691089  0.380715
# 6   0.658237  0.912069  0.515689
# 5   0.774367  0.962417  0.636606
# 4   0.163570  0.179510  0.674561
# 3   0.947437  0.340978  0.962509
# 2   0.049101  0.393013  0.543733
# 1   0.753733  0.401856  0.030838
# 0   0.622493  0.788445  0.867439

# %%
#axis = 0 is row
#axis = 1 is column

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#            2         1         0
# 0   0.867439  0.788445  0.622493
# 1   0.030838  0.401856  0.753733
# 2   0.543733  0.393013  0.049101
# 3   0.962509  0.340978  0.947437
# 4   0.674561  0.179510  0.163570
# 5   0.636606  0.962417  0.774367
# 6   0.515689  0.912069  0.658237
# 7   0.380715  0.691089  0.245886
# 8   0.153341  0.864545  0.836300
# 9   0.487569  0.068195  0.776664
# 10  0.851256  0.308509  0.529771
# 11  0.452129  0.838086  0.124794

# %%
newdf2 = newdf # this will only create a view of newdf, changes made in newdf2 will be reflected in newdf

# %%
newdf2 = newdf.copy() # changes made to newdf2 will not reflect in newdf

# %%
newdf.loc[0,0] = 0.348

# %%
newdf.head(2)
# Out:
#           0         1         2
# 0  0.348000  0.788445  0.867439
# 1  0.753733  0.401856  0.030838

# %%
newdf.columns = list("ABC")

# %%
newdf
# Out:
#            A         B         C
# 0   0.348000  0.788445  0.867439
# 1   0.753733  0.401856  0.030838
# 2   0.049101  0.393013  0.543733
# 3   0.947437  0.340978  0.962509
# 4   0.163570  0.179510  0.674561
# 5   0.774367  0.962417  0.636606
# 6   0.658237  0.912069  0.515689
# 7   0.245886  0.691089  0.380715
# 8   0.836300  0.864545  0.153341
# 9   0.776664  0.068195  0.487569
# 10  0.529771  0.308509  0.851256
# 11  0.124794  0.838086  0.452129

# %%
newdf.loc[0,'A'] = 0.121212

# %%
newdf
# Out:
#            A         B         C
# 0   0.121212  0.788445  0.867439
# 1   0.753733  0.401856  0.030838
# 2   0.049101  0.393013  0.543733
# 3   0.947437  0.340978  0.962509
# 4   0.163570  0.179510  0.674561
# 5   0.774367  0.962417  0.636606
# 6   0.658237  0.912069  0.515689
# 7   0.245886  0.691089  0.380715
# 8   0.836300  0.864545  0.153341
# 9   0.776664  0.068195  0.487569
# 10  0.529771  0.308509  0.851256
# 11  0.124794  0.838086  0.452129

# %%
newdf = newdf.drop(11,axis=0)

# %%
newdf.loc[[1,2],['B','C']]
# Out:
#           B         C
# 1  0.401856  0.030838
# 2  0.393013  0.543733

# %%
newdf.loc[:,['B','C']]
# Out:
#            B         C
# 0   0.788445  0.867439
# 1   0.401856  0.030838
# 2   0.393013  0.543733
# 3   0.340978  0.962509
# 4   0.179510  0.674561
# 5   0.962417  0.636606
# 6   0.912069  0.515689
# 7   0.691089  0.380715
# 8   0.864545  0.153341
# 9   0.068195  0.487569
# 10  0.308509  0.851256

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C
# 1  0.753733  0.401856  0.030838
# 2  0.049101  0.393013  0.543733

# %%
newdf['A']
# Out:
# 0     0.121212
# 1     0.753733
# 2     0.049101
# 3     0.947437
# 4     0.163570
# 5     0.774367
# 6     0.658237
# 7     0.245886
# 8     0.836300
# 9     0.776664
# 10    0.529771
# Name: A, dtype: float64

# %%
newdf[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#           A         B         C
# 0  0.121212  0.788445  0.867439
# 2  0.049101  0.393013  0.543733
# 4  0.163570  0.179510  0.674561
# 7  0.245886  0.691089  0.380715

# %%
newdf.iloc[0,2]
# Out:
# 0.8674392769998961

# %%
newdf.iloc[[0,2],[1,2]]
# Out:
#           B         C
# 0  0.788445  0.867439
# 2  0.393013  0.543733

# %%
newdf.drop(['A'],axis=1)
# Out:
#            B         C
# 0   0.788445  0.867439
# 1   0.401856  0.030838
# 2   0.393013  0.543733
# 3   0.340978  0.962509
# 4   0.179510  0.674561
# 5   0.962417  0.636606
# 6   0.912069  0.515689
# 7   0.691089  0.380715
# 8   0.864545  0.153341
# 9   0.068195  0.487569
# 10  0.308509  0.851256

# %%
newdf
# Out:
#            A         B         C
# 0   0.121212  0.788445  0.867439
# 1   0.753733  0.401856  0.030838
# 2   0.049101  0.393013  0.543733
# 3   0.947437  0.340978  0.962509
# 4   0.163570  0.179510  0.674561
# 5   0.774367  0.962417  0.636606
# 6   0.658237  0.912069  0.515689
# 7   0.245886  0.691089  0.380715
# 8   0.836300  0.864545  0.153341
# 9   0.776664  0.068195  0.487569
# 10  0.529771  0.308509  0.851256

# %%
newdf.drop(['C'],axis=1,inplace=True)

# %%
newdf
# Out:
#            A         B
# 0   0.121212  0.788445
# 1   0.753733  0.401856
# 2   0.049101  0.393013
# 3   0.947437  0.340978
# 4   0.163570  0.179510
# 5   0.774367  0.962417
# 6   0.658237  0.912069
# 7   0.245886  0.691089
# 8   0.836300  0.864545
# 9   0.776664  0.068195
# 10  0.529771  0.308509

# %%
newdf.drop([1,5],axis=0,inplace=True)

# %%
newdf
# Out:
#            A         B
# 0   0.121212  0.788445
# 2   0.049101  0.393013
# 3   0.947437  0.340978
# 4   0.163570  0.179510
# 6   0.658237  0.912069
# 7   0.245886  0.691089
# 8   0.836300  0.864545
# 9   0.776664  0.068195
# 10  0.529771  0.308509

# %%
newdf.head(3)
# Out:
#           A         B
# 0  0.121212  0.788445
# 2  0.049101  0.393013
# 3  0.947437  0.340978

# %%
newdf.reset_index()
# Out:
#    index         A         B
# 0      0  0.121212  0.788445
# 1      2  0.049101  0.393013
# 2      3  0.947437  0.340978
# 3      4  0.163570  0.179510
# 4      6  0.658237  0.912069
# 5      7  0.245886  0.691089
# 6      8  0.836300  0.864545
# 7      9  0.776664  0.068195
# 8     10  0.529771  0.308509

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#           A         B
# 0  0.121212  0.788445
# 1  0.049101  0.393013
# 2  0.947437  0.340978
# 3  0.163570  0.179510
# 4  0.658237  0.912069
# 5  0.245886  0.691089
# 6  0.836300  0.864545
# 7  0.776664  0.068195
# 8  0.529771  0.308509

# %%
newdf['B'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: B, dtype: bool

# %%
newdf['B'] = None

# %%
newdf
# Out:
#           A     B
# 0  0.121212  None
# 1  0.049101  None
# 2  0.947437  None
# 3  0.163570  None
# 4  0.658237  None
# 5  0.245886  None
# 6  0.836300  None
# 7  0.776664  None
# 8  0.529771  None

# %%
newdf['B'].isnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# Name: B, dtype: bool

# %%
newdf.loc[:,['B']] = None

# %%
newdf
# Out:
#           A     B
# 0  0.121212  None
# 1  0.049101  None
# 2  0.947437  None
# 3  0.163570  None
# 4  0.658237  None
# 5  0.245886  None
# 6  0.836300  None
# 7  0.776664  None
# 8  0.529771  None

# %%
df.dropna()
# Out:
#              name  marks       city
# first        kali     99      delhi
# second     kavita     99     mumbai
# third   shubhangi     10  bangalore

# %%
df.dropna(how='all')
# Out:
#              name  marks       city
# first        kali     99      delhi
# second     kavita     99     mumbai
# third   shubhangi     10  bangalore

# %%
df.drop_duplicates()
# Out:
#              name  marks       city
# first        kali     99      delhi
# second     kavita     99     mumbai
# third   shubhangi     10  bangalore

# %%
df.drop_duplicates(subset=['name'],keep='last') #keep= False keep='first
# Out:
#              name  marks       city
# first        kali     99      delhi
# second     kavita     99     mumbai
# third   shubhangi     10  bangalore

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, first to third
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   marks   3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df['name'].value_counts(dropna=False)
# Out:
# kali         1
# kavita       1
# shubhangi    1
# Name: name, dtype: int64

# %%
df.notnull()
# Out:
#         name  marks  city
# first   True   True  True
# second  True   True  True
# third   True   True  True

# %%
data = [{'a' : 1 , 'b' : 2, 'c' : 3},{'a' : 4, 'b' : 5, 'c' : 6}]

# %%
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
df.mean()
# Out:
# <ipython-input-116-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# marks    69.333333
# dtype: float64

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   69.333333
# std    51.384174
# min    10.000000
# 25%    54.500000
# 50%    99.000000
# 75%    99.000000
# max    99.000000

# %%
df.corr()
# Out:
#        marks
# marks    1.0

# %%
df.max()
# Out:
# name     shubhangi
# marks           99
# city        mumbai
# dtype: object

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
df3 = pd.read_excel("/content/weather_data (2).xlsx")

# %%
df3
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow
