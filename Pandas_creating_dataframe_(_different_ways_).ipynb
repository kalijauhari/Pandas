# %% [markdown]
# <a href="https://colab.research.google.com/github/kalijauhari/Pandas/blob/main/Pandas_creating_dataframe_(_different_ways_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/kalijauhari/Pandas/main/weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df['Evaporation'].max()
# Out:
# 13.8

# %%
df['RainToday'][df['RainTomorrow']=='Yes']
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 8       No
#       ...
# 326     No
# 337     No
# 338    Yes
# 340     No
# 347     No
# Name: RainToday, Length: 66, dtype: object

# %%
df['Evaporation'].mean()
# Out:
# 4.521857923497268

# %%
df['WindGustSpeed'].mean()
# Out:
# 39.84065934065934

# %%
df.fillna(0,inplace=True)
df['WindGustSpeed'].mean()
# Out:
# 39.622950819672134

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/2_dataframe_basics/weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
rows , columns = df.shape

# %%
columns
# Out:
# 4

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day # or df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# Index(['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'], dtype='object', name='day')

# %%
df.loc['1/2/2017']
# Out:
# temperature       35
# windspeed          7
# event          Sunny
# Name: 1/2/2017, dtype: object

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.set_index('event',inplace=True) # this is kind of building a hash map using event as a key
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %%
#different ways of creating dataframe

# %%
import pandas as pd
pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/3_different_ways_of_creating_dataframe/weather_data.csv")
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df = pd.read_table("https://github.com/kalijauhari/Pandas/blob/main/weather_data.xlsx","Sheet1")
df
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: In a future version of pandas all arguments of read_table except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-64-6ab4212ee85d>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_table("https://github.com/kalijauhari/Pandas/blob/main/weather_data.xlsx","Sheet1")
#                                         <!DOCTYPE html>
# 0     <html lang="en" data-color-mode="auto" data-li...
# 1                                                <head>
# 2                                <meta charset="utf-8">
# 3     <link rel="dns-prefetch" href="https://github....
# 4     <link rel="dns-prefetch" href="https://avatars...
# ...

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
#Using tuples list
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
#Using list of dictionaries
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
